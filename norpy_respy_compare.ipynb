# %%
import numpy as np
import pandas as pd
import pybobyqa

from norpy import simulate
from norpy.model_spec import get_random_model_specification, get_model_obj
from smm_prep import get_moments, get_weigthing_matrix
from norpy.adapter.SimulationBasedEstimation import SimulationBasedEstimationCls
from optimizers.auxiliray_pyogba import wrapper_pybobyqa
from auxiliary import moments_final, weigthing_final

# %%
#Specify the location of structural parameters in the optim variable 
optim_paras = {
    "coeffs_common": slice(0,2),
    "coeffs_home": slice(2,4),
    "coeffs_edu": slice(4, 10),
    "coeffs_work": slice(10, 22),
    "type_spec_shifts": slice(22, 31),
    "shocks_cov": slice(31, 40),

}

#Specify positions that vary and positions that are kept fixed 
pos_dict = {
    "coeffs_common": None,
    "coeffs_home": [0, 2],
    "coeffs_edu": list(range(6)),
    "coeffs_work": list(range(0, 7)) + list(range(8, 13)),
    "type_spec_shifts": list(range(3, 12)),
    "shocks_cov": None
}

#Specify box bounds for the optimization 
box_dict = {
    "coeffs_common": [(-15000, 5000),
                      (-15000, 50000)],
    "coeffs_home": [(0.0, 250000.0),
                    (1000.0, 6000.0)
                    ],
    "coeffs_edu": [(-16000.0, -5000.0),
                   (-1000000.0, 500000.0),
                   (-1500000.0, 1000),
                   (-300000.0, -100000.0),
                   (-400000.0, 20000.0),
                   (-300000.0, -1000.0)
                   ],
    "coeffs_work": [(10.5, 12.1),
                    (0.0, 0.2),
                    (0.0, 0.05),
                    (-0.04, 0.0),
                    (0.0, 0.15),
                    (0.0, 0.1),
                    (-0.1, 0.1),
                    (0.0, 0.2),
                    (0.0, 0.5),
                    (-100000.0, 100000.0),
                    (-250000.0, 100000.0),
                    (-100000.0, 100000.0),
                    ],
    "type_spec_shifts": [(-1, 1.0),
                         (-100000.0, 100000.0),
                         (-100000.0, 100000.0),
                         (-1, 1.0),
                         (-100000.0, 100000.0),
                         (-100000.0, 100000.0),
                         (-1, 1.0),
                         (-100000.0, 100000.0),
                         (-100000.0, 100000.0),
                         ],
    "shocks_cov": [(-10, 10),
                   (-100000, 100000),
                   (-100000, 100000),
                   (-100000, 100000),
                   (-1000000000, 100000000000),
                   (-100000, 100000),
                   (-100000, 100000),
                   (-100000, 100000),
                    (-10000000000, 100000000000)
                   ]

}

# %%
#Specify the dictionary for the model specification 
model_spec_dict = {
            "num_periods": 49,
            "num_agents_sim": 5000,
            "num_draws_emax": 5000,
            "num_types": 4,
            "num_edu_start": 1,
            "start_age":17,
            "edu_max": 25,
            "seed_sim": 132,
            "seed_emax": 456,
            "edu_range_start": np.array([9]),
            "type_shares": np.array([0.0,
                                     0.0,
                                     0.083296202210043,
                                     0.0,
                                     -1.166351815552428,
                                     0.0,
                                     0.560420764935477,
                                     0.0
                                    ]),
            "initial_lagged_schooling_prob": float(1),
            "delta": 0.926,
            "shocks_cov":np.array([ 1.02400000e-01, -5.47200000e-02, -7.80800000e-02,
                                   -5.47200000e-02,  5.70577589e+10, -7.64376094e+04,
                                   -7.80800000e-02, -7.64376094e+04,  3.15842153e+10]
                                 ).reshape(3,3),
            "coeffs_home": np.array([118298.619219974672887,
                                     0,
                                     5002.729695187197649
                                     ]),
            "coeffs_edu": np.array([-12095.401873979237280,
                                    -299318.752652849536389,
                                    -145180.005109090765473,
                                    -264622.915707175270654,
                                    -230544.888455883046845,
                                    -7246.006801301322412,
                                    0
                                    ]),

            "coeffs_work": np.array([11.208202053369439,
                                     0.097513358678320,
                                     0.018614181282294,
                                     -0.029874125213061,
                                     0.039423863168125,
                                     0.030096500914825,
                                     0.000604371633589,
                                     0.000000000000000,
                                     0.102604480018636,
                                     0.316817020463839,
                                     35975.477362620003987,
                                     -174807.501464794069761,
                                     34831.665739499643678]),

            "coeffs_common": np.array([-12008.359773063100874,
                                       48942.700331236468628
                                       ]),
            "type_spec_shifts": np.array([0,
                                          0,
                                          0,
                                          0.176162183496461,
                                          9662.726586080767447,
                                          -5137.074427099956665,
                                          -0.520489768432775,
                                          -46004.947807452808775,
                                          11954.110836926454795,
                                          0.066716619965600,
                                          -31343.568694616944413,
                                          -7246.492439852168900
                                          ]).reshape(4,3)
                                          }

#Initialize the model class instance
initialization_object = get_model_obj(model_spec_dict)

# define paras for optimizer
max_evals = 1000000

# %%
#Run the simulation with the specified dict 
sim_norpy_respy_pars = simulate(initialization_object).replace({"wages":{-99:np.nan}})

# %%
#Inspect simulated moments and compare to observed moments
moments_norpy_respy_sim = get_moments(sim_norpy_respy_pars)

# %%
#Specify all input arguments required to initialize the smm class 
args = (
    model_spec_dict,
    moments_final,
    weigthing_final,
    get_moments,
    optim_paras,
    pos_dict,
    max_evals
)

#Initialize smm object 
adapter_smm = SimulationBasedEstimationCls(*args)

# %%
#Put box bounds in appropriate form 
box_lower = np.array([y[0] for x in box_dict.keys() for y in box_dict[x] ])
box_upper = np.array([y[1] for x in box_dict.keys()for y in box_dict[x] ])

#Specify kwargs for the optimizer
kwargs = dict()
kwargs['scaling_within_bounds'] = True
kwargs['bounds'] = (box_lower, box_upper)
kwargs['objfun_has_noise'] = True
kwargs['maxfun'] = 10e6

# %%
#Run the estimation 
rslt = pybobyqa.solve(adapter_smm.evaluate, adapter_smm.free_params, **kwargs)
# Out:
# /home/moritz/anaconda3/envs/dev_norpy/lib/python3.6/site-packages/pybobyqa/solver.py:769: RuntimeWarning: x0 too close to upper bound, adjusting
#   warnings.warn("x0 too close to upper bound, adjusting", RuntimeWarning)
# /home/moritz/OpenSourceEconomics/norpy/norpy/simulate/simulate.py:72: RuntimeWarning: covariance is not symmetric positive-semidefinite.
#   periods_draws_emax = np.random.multivariate_normal(*args)

# %%
moments_norpy_respy_sim
# Out:
# OrderedDict([('Wage Distribution',
#               OrderedDict([(1.0, [220583.18901547504, 86878.41222570468]),
#                            (2.0, [261793.25979713528, 102346.91820783891]),
#                            (3.0, [299665.6850008106, 112524.0889518826]),
#                            (4.0, [328463.8544585566, 123316.4633282078]),
#                            (5.0, [373257.82730718295, 146734.98539998438]),
#                            (6.0, [387779.70195092174, 154579.33352521673]),
#                            (7.0, [403551.41267841635, 154907.28383889468]),
#                            (8.0, [449292.0029961793, 195014.37573388478]),
#                            (9.0, [466840.1720331021, 197234.5377328065]),
#                            (10.0, [480894.9873384872, 209012.70168905964]),
#                            (11.0, [496541.9040483903, 212483.40967167754]),
#                            (12.0, [508731.74968757207, 218814.75350393174]),
#                            (13.0, [513086.57310557587, 220685.58356365107]),
#                            (14.0, [531083.2042968073, 230293.8150065648]),
#                            (15.0, [536042.0928697096, 235616.35312157957]),
#                            (16.0, [544216.9866958765, 236577.9603898923]),
#                            (17.0, [552644.5378362874, 238813.1306224036]),
#                            (18.0, [566781.4623668602, 249981.47686145944]),
#                            (19.0, [569730.8177376905, 245389.56308966185]),
#                            (20.0, [579708.3615544111, 253179.38107545968]),
#                            (21.0, [585726.6757580466, 254756.34893153387]),
#                            (22.0, [597827.3266395146, 264810.3739956581]),
#                            (23.0, [605566.513549645, 264579.0607178661]),
#                            (24.0, [601110.4243326191, 263024.7082458974]),
#                            (25.0, [614999.9813307, 269307.39880217495]),
#                            (26.0, [618585.2019202451, 263536.36493506527]),
#                            (27.0, [626848.6597493611, 274179.94585180224]),
#                            (28.0, [630323.4401540172, 272731.6528680315]),
#                            (29.0, [633337.9699254354, 278502.12347432383]),
#                            (30.0, [635273.7093003363, 280142.1874720411]),
#                            (31.0, [640549.0062153148, 282651.7442852759]),
#                            (32.0, [644874.466286104, 282158.2161084371]),
#                            (33.0, [642742.3316802839, 277937.43824675656]),
#                            (34.0, [640448.5510974636, 276407.94999801]),
#                            (35.0, [648866.7676440341, 283067.59862076055]),
#                            (36.0, [651566.3188176329, 279782.8764631441]),
#                            (37.0, [645796.4869355094, 276099.24120991916]),
#                            (38.0, [652543.3302182647, 282906.6917229691]),
#                            (39.0, [658425.6822215329, 282869.7222366392]),
#                            (40.0, [655199.1175888187, 282347.9072794078]),
#                            (41.0, [659986.3105520003, 279350.28926695546]),
#                            (42.0, [652621.5486587724, 279743.8368865843]),
#                            (43.0, [650945.7877306476, 275198.1525131492]),
#                            (44.0, [654960.3603463478, 277080.93411148683]),
#                            (45.0, [646040.1975359103, 270961.26441131963]),
#                            (46.0, [651714.8255104786, 285053.4048192813]),
#                            (47.0, [646770.4159909082, 274210.63581247575]),
#                            (48.0, [659342.630500166, 271710.2876971235]),
#                            (49.0, [681817.8289964005, 274087.8474247217])])),
#              ('Choice Probability',
#               OrderedDict([(1.0, [0.1816, 0.7682, 0.0502]),
#                            (2.0, [0.3442, 0.6136, 0.0422]),
#                            (3.0, [0.4664, 0.505, 0.0286]),
#                            (4.0, [0.6346, 0.3408, 0.0246]),
#                            (5.0, [0.6712, 0.3118, 0.017]),
#                            (6.0, [0.6794, 0.301, 0.0196]),
#                            (7.0, [0.8274, 0.157, 0.0156]),
#                            (8.0, [0.8612, 0.1216, 0.0172]),
#                            (9.0, [0.8808, 0.1032, 0.016]),
#                            (10.0, [0.9046, 0.0796, 0.0158]),
#                            (11.0, [0.9176, 0.065, 0.0174]),
#                            (12.0, [0.9278, 0.054, 0.0182]),
#                            (13.0, [0.9358, 0.0474, 0.0168]),
#                            (14.0, [0.9454, 0.0374, 0.0172]),
#                            (15.0, [0.9564, 0.026, 0.0176]),
#                            (16.0, [0.9522, 0.0266, 0.0212]),
#                            (17.0, [0.9576, 0.02, 0.0224]),
#                            (18.0, [0.9606, 0.0186, 0.0208]),
#                            (19.0, [0.964, 0.0138, 0.0222]),
#                            (20.0, [0.9654, 0.0102, 0.0244]),
#                            (21.0, [0.9662, 0.0076, 0.0262]),
#                            (22.0, [0.9646, 0.008, 0.0274]),
#                            (23.0, [0.9646, 0.0054, 0.03]),
#                            (24.0, [0.964, 0.0044, 0.0316]),
#                            (25.0, [0.9644, 0.0022, 0.0334]),
#                            (26.0, [0.9622, 0.0016, 0.0362]),
#                            (27.0, [0.9586, 0.002, 0.0394]),
#                            (28.0, [0.9598, 0.0014, 0.0388]),
#                            (29.0, [0.9616, 0.0012, 0.0372]),
#                            (30.0, [0.9616, 0.0004, 0.038]),
#                            (31.0, [0.9548, 0.0006, 0.0446]),
#                            (32.0, [0.951, 0.0004, 0.0486]),
#                            (33.0, [0.95, 0.0004, 0.0496]),
#                            (34.0, [0.9508, 0.0002, 0.049]),
#                            (35.0, [0.9466, 0.0, 0.0534]),
#                            (36.0, [0.9422, 0.0006, 0.0572]),
#                            (37.0, [0.9432, 0.0, 0.0568]),
#                            (38.0, [0.9404, 0.0002, 0.0594]),
#                            (39.0, [0.9366, 0.0, 0.0634]),
#                            (40.0, [0.933, 0.0, 0.067]),
#                            (41.0, [0.9282, 0.0, 0.0718]),
#                            (42.0, [0.9222, 0.0, 0.0778]),
#                            (43.0, [0.9246, 0.0, 0.0754]),
#                            (44.0, [0.9208, 0.0, 0.0792]),
#                            (45.0, [0.9154, 0.0, 0.0846]),
#                            (46.0, [0.9166, 0.0, 0.0834]),
#                            (47.0, [0.9084, 0.0, 0.0916]),
#                            (48.0, [0.8852, 0.0, 0.1148]),
#                            (49.0, [0.7674, 0.0, 0.2326])]))])
